# %%
import nltk
from nltk.tokenize import word_tokenize, RegexpTokenizer
import re
import copy
from collections import defaultdict , Counter
import math
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

def custom_tokenize( text, must_have_textnum=True):
    # Regular expression pattern to match quoted text
    quote_pattern = r'\".*?\"|\`.*?\`|\'.*?\''
    
    # Find all quoted texts
    quoted_texts = nltk.re.findall(quote_pattern, text)

    # Replace quoted texts with placeholders to avoid re-tokenization
    placeholder = "QUOTE_PLACE_HOLDER"
    modified_text = nltk.re.sub(quote_pattern, placeholder, text)

    # Tokenize the modified text using word_tokenize
    tokens = word_tokenize(modified_text)

    # Replace placeholders with the original quoted texts
    final_tokens = []
    quote_index = 0
    for token in tokens:
        if token == placeholder:
            final_tokens.append(quoted_texts[quote_index])
            quote_index += 1
        else:
            final_tokens.append(token)

    return [s for s in final_tokens if re.search(r'[a-zA-Z0-9]', s)] if must_have_textnum else final_tokens

#calculating the similarity score of the two tokenized sentences.
def similarity_meassure( hypothesis_tokens , reference_tokens, in_table_keywords):

    hypothesis_counts = Counter(hypothesis_tokens)
    reference_counts = Counter(reference_tokens)
    clipped_counts = dict()

    for token in hypothesis_tokens:
        if token not in reference_counts.keys():
            reference_counts[token] = 0
        if token in in_table_keywords:
            clipped_counts[token] = min(hypothesis_counts[token], reference_counts[token])
            # print(f'{token}')
        else:
            clipped_counts[token] = min(hypothesis_counts[token], reference_counts[token])/2
    
    total_clipped = sum(clipped_counts.values())

    similarity = (total_clipped*2+0.1) / ( len(hypothesis_tokens) + len(reference_tokens) + 0.1 )

    return similarity

def ensemble( decoded_text_list , inputs_log_prob, batch_text, similarity_func='avg' ):# , past_key_value_tensor ):
    #function for performing ensemble using the bleu metric between the candidate sequences.
    #input:
        #inputs_ids: torch tensor representing the prompt tokens per component with shape (batch_size , input_len , num_beam)
        #inputs_log_prob: torch tensor representing the probability of each input_ids with the shape(batch_size , 1 , num_beam)
        #starting_batch_input_len: The length of the batch before any predictions.
        #extra_added_paddings: torch tensor with size (batch_size , 1 , num_beam) recording the token index of the last token of the prompt (where the answer starts)
        #batch_text: list of string with len()=number_components. Having the prompts for each components.
    #return:
        #ensembled_inputs_ids: torch tensor with size (batch_size , input_len , num_beam)
        #ensembled_inputs_log_prob: torch tensor with size (batch_size , 1 , num_beam)
    # print('extra_added_paddings before ensemble: ' , extra_added_paddings)
    length_penalty = 0.5
    table_creation_part_prompt = batch_text.split('database schema :')[-1]
    # print('table_creation_part_prompt: ', table_creation_part_prompt)
    in_table_keywords = custom_tokenize( table_creation_part_prompt.replace('.' , ' ')  )
    # print('in_table_keywords: ' , in_table_keywords)
    tokenized_responses = []
    for text in decoded_text_list: #number of candidates we have for each question
        tokenized_responses.append( custom_tokenize( text.replace('.' , ' ')))#, must_have_textnum=False ) )
        
    selection_score_list = [] #This scoring is used to select the best candidates. It uses the length penalty to calculate the scores

    tmp_input_log_prob = []
    for text, prob in zip(decoded_text_list , inputs_log_prob):
        gen_text_len = len( tokenizer(text, return_tensors="pt" , padding=True).input_ids )
        tmp_input_log_prob.append( prob/( gen_text_len ** length_penalty ) )

    #Calculating the score for each candidate
    for j in range( len( tokenized_responses ) ): #[tok_component1_beam1, tok_component2_beam1, tok_component3_beam1, ..., tok_component1_beam2, tok_component2_beam2 , ...]
        temp_tokenized_responses = copy.deepcopy( tokenized_responses )
        temp_query_list = decoded_text_list.copy()
        query = temp_query_list.pop(j)
        tokenized_response = temp_tokenized_responses.pop(j)
        selection_score = 0
        selection_denominator = 0
        for index , (other_tokenized_response, other_query) in enumerate( zip( temp_tokenized_responses , temp_query_list ) ):
            if index>=j:
                index+=1
    
            if query=='':
                query='***weirdanswer***'
            elif other_query=='':
                other_query='***weirdanswer***'
            
            jacc_weighted_sim = similarity_meassure( tokenized_response, other_tokenized_response, in_table_keywords )

            if similarity_func == 'jacc':
                similarity = math.log(jacc_weighted_sim)
            elif similarity_func == 'tree':
                tree_based_sim = sql_scoring.unparsed_query_similarity(query , other_query)
                if tree_based_sim == 0:
                    similarity = math.log(jacc_weighted_sim)
                else:
                    similarity = math.log( tree_based_sim )
            elif similarity_func == 'bleu':
                blue_score = sentence_bleu( word_tokenize( query.replace('.' , ' ') ) , word_tokenize( other_query.replace('.' , ' ') ) , smoothing_function = SmoothingFunction().method1)
                if blue_score == 0:
                    similarity = math.log(jacc_weighted_sim)
                else:
                    similarity = math.log( blue_score )
                    
            prob_with_lenpen = torch.tensor( tmp_input_log_prob[ index ] )
            selection_score_with_other_response = prob_with_lenpen + similarity
            
            if selection_score == 0:
                selection_score = selection_score_with_other_response
                selection_denominator = prob_with_lenpen
            else:
                alpha = max( selection_score_with_other_response , selection_score )
                beta = min( selection_score_with_other_response , selection_score )
                selection_score = alpha + torch.log1p(torch.exp(beta-alpha))

                alpha = max( prob_with_lenpen , selection_denominator )
                beta = min( prob_with_lenpen , selection_denominator )
                selection_denominator = alpha + torch.log1p(torch.exp(beta-alpha))

        selection_log_score = (selection_score/ selection_denominator + tmp_input_log_prob[ j ] )#/2
        selection_score_list.append(selection_log_score)

    max_bleu_score_value = max( selection_score_list )
    max_index_bleu_score = selection_score_list.index(max_bleu_score_value)
    
    return decoded_text_list[max_index_bleu_score]


# prompt_list
# responses_list
# probabilities_list
output_list = []
for index in range( len(responses_list[0]) ):
    candids = []
    probs = []
    prompt = prompt_list[index]
    for comp in range( len(responses_list) ):
        candids.append(responses_list[comp][index])
        probs.append(probabilities_list[comp][index])
    
    output_list.append( ensemble( candids , probs , prompt , similarity_func='bleu') )
        
with open('../final_output_CodeS_preprocess_ensemble.pkl' , 'wb') as f:
    pkl.dump(output_list , f)

# %%
from codes.utils.db_utils import check_sql_executability, detect_special_char

def get_candidates_from_dirList(dir_list):
    #returns:
        #inputs_log_probs_list: list of list of torch tensors: [  [q0_comp0, q1_comp0 , ...], ... , [q0_compN, q1_compN , ... ] ]
        #all_candidates : list of list of strings: [ [ [comp0_q0_beam0, ... , comp0_q0_beamM] , ... , [comp0_qN_beam0, ... , comp0_qN_beamM] ] , ... , [ [compK_q0_beam0, ... , comp0K_q0_beamM] , ... , [compK_qN_beam0, ... , compK_qN_beamM] ]  ] 
    input_ids_corss_component_list = []
    starting_batch_input_len_cross_comp_lst = []
    inputs_log_probs_list = []
    all_candidates = []
    for the_dir in dir_list:
        with open( the_dir + '/output_sequences_test_lenpen05_input_ids.pkl' , 'rb' ) as f:
            input_ids_corss_component_list.append( pkl.load(f) )
            
        with open( the_dir + '/output_sequences_test_lenpen05_starting_batch_input_len.pkl' , 'rb' ) as f:
            starting_batch_input_len_cross_comp_lst.append( pkl.load(f) )

        with open(the_dir + '/output_sequences_test_lenpen05_inputs_log_prob.pkl', 'rb') as f:
            inputs_log_probs_list.append( pkl.load(f) )
    
    for component in range( len(input_ids_corss_component_list) ):
        candidate_list = []
        for index in range( len( input_ids_corss_component_list[0] ) ):
            start = starting_batch_input_len_cross_comp_lst[component][index]
            the_tensor = input_ids_corss_component_list[component][index][start:, :].transpose(0 , 1)
            candidate_list.append( tokenizer.batch_decode( the_tensor , skip_special_tokens=True ) )
        all_candidates.append(candidate_list)
    return all_candidates, inputs_log_probs_list

def post_process(sql, schema_items):
    sql = sql.replace("\n", " ")
    for table in schema_items:
        for column_name in table["column_names"]:
            if detect_special_char(column_name) and column_name in sql:
                sql = sql.replace(column_name, "`"+column_name+"`")

    while "``" in sql:
        sql = sql.replace("``", "`")

    sql = sql.split(";")[0].strip() + ";"

    return sql

with open('./codes/eval_set.pkl' , 'rb')as f:
    eval_set = pkl.load(f)

def codeS_postProcess( generated_sqls , q_index ):
    eval_data = eval_set[q_index]
    generated_sqls = [ post_process( generated_sql, eval_data["schema"]["schema_items"] ) for generated_sql in generated_sqls ]
    return generated_sqls

# %%
#This code is written as a prerequisite for my scoring method in sequence-level fashion that has already have had the CodeS ensemble on the components.
#Getting the selected queries by CodeS and their probabilities. Storing them in pkl files
import json
output_file = 'myScoringMethod_treeBased_ens_after_CodeS_ens_5comp.pkl'
dir_list = [ '../bird_0_5_lenpen05' , '../bird_5_10_lenpen05' , '../bird_10_15_lenpen05' , '../bird_15_20_lenpen05' , '../bird_20_25_lenpen05' ]

tokenizer = AutoTokenizer.from_pretrained('seeklhy/codes-1b')

comp1 = '../codeS_pred/codes-1b_beam4_lenpen05_BIRD_table_num_5_column_num_6_5-shot_0_5_max_tokens_8192_max_new_tokens_256.json'
comp2 = '../codeS_pred/codes-1b_beam4_lenpen05_BIRD_table_num_5_column_num_6_5-shot_5_10_max_tokens_8192_max_new_tokens_256.json'
comp3 = '../codeS_pred/codes-1b_beam4_lenpen05_BIRD_table_num_5_column_num_6_5-shot_10_15_max_tokens_8192_max_new_tokens_256.json'
comp4 = '../codeS_pred/codes-1b_beam4_lenpen05_BIRD_table_num_5_column_num_6_5-shot_15_20_max_tokens_8192_max_new_tokens_256.json'
comp5 = '../codeS_pred/codes-1b_beam4_lenpen05_BIRD_table_num_5_column_num_6_5-shot_20_25_max_tokens_8192_max_new_tokens_256.json'

#Reading the selected questions from each component into responses_list
comp_list = [ comp1 , comp2 , comp3 , comp4 , comp5 ]
responses_list = [] # [ [comp0_q0, comp0q1, comp0_q2 , ...] , [comp1_q0, comp1_q1, ...] , ... ]
for comp in comp_list:
    responses = []
    with open(comp , 'r') as f:
        generated_response_file_byte = f.read()
        generated_response = json.loads(generated_response_file_byte)
        for item in generated_response['questions']:
            responses.append(item['response'])
    responses_list.append(responses)

probabilities_list = [ [] for comp in comp_list ] # We want to store the probability of each selected candidate in each component here.
each_comp_candids , inputs_log_probs_list = get_candidates_from_dirList(dir_list) #[ [ [comp0_q0_beam0, ... , comp0_q0_beamM] , ... , [comp0_qN_beam0, ... , comp0_qN_beamM] ] , ... , [ [compK_q0_beam0, ... , comp0K_q0_beamM] , ... , [compK_qN_beam0, ... , compK_qN_beamM] ]  ] 
num_comp = len(comp_list)
for comp_index in range(num_comp) :
    print('the component that we are processing: ' , comp_index)
    this_comp_selected_q = responses_list[comp_index]
    this_comp_candids = each_comp_candids[comp_index]
    this_comp_candid_probs = inputs_log_probs_list[comp_index]
    for q_index in range( len(this_comp_selected_q) ):
        print('The question we are processing: ', q_index)
        selected_q = this_comp_selected_q[q_index]
        last_beams = codeS_postProcess( this_comp_candids[q_index] , q_index)
        candid_probs = this_comp_candid_probs[q_index]
        found_any = False
        for beam_index in range(len(last_beams)):
            if selected_q == last_beams[beam_index]:
                probabilities_list[comp_index].append( candid_probs[0,beam_index].item() )
                found_any = True
                break
        if found_any==False:
            probabilities_list[comp_index].append(candid_probs[0,-1].item())
            print(selected_q)
            for i in last_beams:
                print(i)
            print('---------------------------------------------')

prompt_list = []
with open('../components/codes-1b_BIRD_table_num_5_column_num_6_5-shot_0-5_max_tokens_8192_max_new_tokens_256.json' , 'r') as f:
    generated_response_file_byte = f.read()
    generated_response = json.loads(generated_response_file_byte)
    for item in generated_response['questions']:
            prompt_list.append(item['prompt'])
        
with open('BIRD_CodeS_1-5_prompt_list.pkl' , 'wb') as f:
    pkl.dump(prompt_list , f)

with open('5comp_response_list.pkl' , 'wb') as f:
    pkl.dump(responses_list , f)

with open('5comp_probabilities_list.pkl' , 'wb') as f:
    pkl.dump(probabilities_list , f)

# %%
#BLEU score Sequence level ensemble that is ready to have the codeS ensemble after on the sorted candidates
#Sorting in the the following order: 0, 1, 2, 3, 4, 5, 6, ...
#input: the input_ids and starting_batch_input_len of the word-level generated components
#output: a list of strings of size 20*dataset_size ordered by the scoring method
from transformers import AutoTokenizer
import SQLtree_based_similarity as sql_scoring
import pickle as pkl
import torch
from nltk.tokenize import word_tokenize
from nltk.translate.bleu_score import sentence_bleu

output_file = 'output_CodeS_beam5_lenpen05_BLEU_pureSeqlevelTreebased_OneSQLQwen-32b.pkl'
# dir_list = [ '../bird_0_5_lenpen05' , '../bird_5_10_lenpen05' , '../bird_10_15_lenpen05' , '../bird_15_20_lenpen05' , '../bird_20_25_lenpen05' ]
dir_list = [ '../output_codeS_beam5_bird_lenpen05_0-5shot_OneSQLQwen-32b' , '../output_codeS_beam5_bird_lenpen05_5-10shot_OneSQLQwen-32b' , '../output_codeS_beam5_bird_lenpen05_10-15shot_OneSQLQwen-32b' , '../output_codeS_beam5_bird_lenpen05_15-20shot_OneSQLQwen-32b' , '../output_codeS_beam5_bird_lenpen05_20-25shot_OneSQLQwen-32b' ]

# tokenizer = AutoTokenizer.from_pretrained('seeklhy/codes-1b')
tokenizer = AutoTokenizer.from_pretrained('Qwen/Qwen2.5-Coder-7B-Instruct')
# tokenizer = AutoTokenizer.from_pretrained('Qwen/Qwen2.5-Coder-14B-Instruct-GPTQ-Int8')

input_ids_corss_component_list = []
starting_batch_input_len_cross_comp_lst = []
final_sorted_candidates = []
for the_dir in dir_list:
    # with open( the_dir + '/output_sequences_test_lenpen05_input_ids.pkl' , 'rb' ) as f:
    # with open( the_dir + '_input_ids.pkl' , 'rb' ) as f:
    with open( the_dir + '.pkl' , 'rb' ) as f:
        input_ids_corss_component_list.append( pkl.load(f) )
        
#     # with open( the_dir + '/output_sequences_test_lenpen05_starting_batch_input_len.pkl' , 'rb' ) as f:
#     with open( the_dir + '_starting_batch_input_len.pkl' , 'rb' ) as f:
#         starting_batch_input_len_cross_comp_lst.append( pkl.load(f) )
for index in range( 0, len(input_ids_corss_component_list[0]), 5 ):
    print('progress: ', index/5)
    candidate_list = []
    for component in range( len(input_ids_corss_component_list) ):
#         start = starting_batch_input_len_cross_comp_lst[component][index]
#         the_tensor = input_ids_corss_component_list[component][index][start:, :].transpose(0 , 1)
#         candidate_list.extend( tokenizer.batch_decode( the_tensor , skip_special_tokens=True ) )
        candidate_list.extend(input_ids_corss_component_list[component][index:index+5])
    
    tokenized_responses = []
    for text in candidate_list: #number of candidates we have for each question
        tokenized_responses.append( word_tokenize( text.replace('.' , ' ') ) )

    blue_scores = []
    #Calculating the bleu metrics for each candidate
    for j in range( len( tokenized_responses ) ): #[tok_component1_beam1, tok_component2_beam1, tok_component3_beam1, ..., tok_component1_beam2, tok_component2_beam2 , ...]
        temp_tokenized_responses = tokenized_responses.copy()
        tokenized_response = temp_tokenized_responses.pop(j)
        # Case 1
        blue_score = sentence_bleu( temp_tokenized_responses , tokenized_response )
        # Case 2
        # blue_score = 0
        # for i in temp_tokenized_responses:
        #     blue_score += sentence_bleu( [i] , tokenized_response )
        
        blue_scores.append(blue_score)
        
    sorted_queries = []
    for candid in range( len(candidate_list) ):
        max_bleu_score_value = max( blue_scores )
        max_index_bleu_score = blue_scores.index(max_bleu_score_value)
        blue_scores[ max_index_bleu_score ] = -100
        sorted_queries.append( candidate_list[ max_index_bleu_score ] )
        
    
    final_sorted_candidates.extend(sorted_queries)

with open(output_file , 'wb') as f:
    pkl.dump(final_sorted_candidates , f)
# Out:
# progress:  0.0
# progress:  1.0
# progress:  2.0
# progress:  3.0
# progress:  4.0
# progress:  5.0
# progress:  6.0
# progress:  7.0
# progress:  8.0
# progress:  9.0
# progress:  10.0
# progress:  11.0
# progress:  12.0
# progress:  13.0
# progress:  14.0
# progress:  15.0
# progress:  16.0
# progress:  17.0
# progress:  18.0
# progress:  19.0
# progress:  20.0
# progress:  21.0
# progress:  22.0
# progress:  23.0
# progress:  24.0
# progress:  25.0
# progress:  26.0
# progress:  27.0
# progress:  28.0
# progress:  29.0
# progress:  30.0
# progress:  31.0
# progress:  32.0
# progress:  33.0
# progress:  34.0
# progress:  35.0
# progress:  36.0
# progress:  37.0
# progress:  38.0
# progress:  39.0
# progress:  40.0
# progress:  41.0
# progress:  42.0
# progress:  43.0
# /home/yadegari/miniconda3/envs/yadegari_cpu/lib/python3.12/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# progress:  1499.0
# progress:  1500.0
# progress:  1501.0
# progress:  1502.0
# progress:  1503.0
# progress:  1504.0
# progress:  1505.0
# progress:  1506.0
# progress:  1507.0
# progress:  1508.0
# progress:  1509.0
# progress:  1510.0
# progress:  1511.0
# progress:  1512.0
# progress:  1513.0
# progress:  1514.0
# progress:  1515.0
# progress:  1516.0
# progress:  1517.0
# progress:  1518.0
# progress:  1519.0
# progress:  1520.0
# progress:  1521.0
# progress:  1522.0
# progress:  1523.0
# progress:  1524.0
# progress:  1525.0
# progress:  1526.0
# progress:  1527.0
# progress:  1528.0
# progress:  1529.0
# progress:  1530.0
# progress:  1531.0
# progress:  1532.0
# progress:  1533.0

# %%
#Tree-base Sequence level ensemble that is ready to have the codeS ensemble after on the sorted candidates
#input: the input_ids and starting_batch_input_len of the word-level generated components
#output: a list of strings of size 20*dataset_size ordered by the scoring method
from transformers import AutoTokenizer
import SQLtree_based_similarity as sql_scoring
import pickle as pkl
import torch

from utils.post_process import process_duplication
def post_process_get_sql_from_gentext(gen_text):
    # remove \n and extra spaces
    # print(gen_text)
    sql = " ".join(gen_text.replace("\n", " ").split())
    sql = process_duplication(sql)
    # python version should >= 3.8
    if sql.startswith("SELECT"):
        sql = sql
    elif sql.startswith(" "):
        sql = "SELECT" + sql
    else:
        sql = "SELECT " + sql
    return sql
    
output_file = 'output_CodeS_beam5_lenpen05_TreeBased_pureSeqlevelTreebased_OneSQLQwen-32b.pkl'
# dir_list = [ '../bird_0_5_lenpen05' , '../bird_5_10_lenpen05' , '../bird_10_15_lenpen05' , '../bird_15_20_lenpen05' , '../bird_20_25_lenpen05' ]
dir_list = [ '../output_codeS_beam5_bird_lenpen05_0-5shot_OneSQLQwen-32b' , '../output_codeS_beam5_bird_lenpen05_5-10shot_OneSQLQwen-32b' , '../output_codeS_beam5_bird_lenpen05_10-15shot_OneSQLQwen-32b' , '../output_codeS_beam5_bird_lenpen05_15-20shot_OneSQLQwen-32b' , '../output_codeS_beam5_bird_lenpen05_20-25shot_OneSQLQwen-32b' ]

# tokenizer = AutoTokenizer.from_pretrained('seeklhy/codes-1b')
# tokenizer = AutoTokenizer.from_pretrained('Qwen/Qwen2.5-Coder-7B-Instruct')
# tokenizer = AutoTokenizer.from_pretrained('Qwen/Qwen2.5-Coder-14B-Instruct-GPTQ-Int8')

input_ids_corss_component_list = []
starting_batch_input_len_cross_comp_lst = []
final_sorted_candidates = []
for the_dir in dir_list:
    # with open( the_dir + '/output_sequences_test_lenpen05_input_ids.pkl' , 'rb' ) as f:
    # with open( the_dir + '_input_ids.pkl' , 'rb' ) as f:
    with open( the_dir + '.pkl' , 'rb' ) as f:
        input_ids_corss_component_list.append( pkl.load(f) )
        
    # with open( the_dir + '/output_sequences_test_lenpen05_starting_batch_input_len.pkl' , 'rb' ) as f:
    # with open( the_dir + '_starting_batch_input_len.pkl' , 'rb' ) as f:
    #     starting_batch_input_len_cross_comp_lst.append( pkl.load(f) )
for index in range( 0, len(input_ids_corss_component_list[0]), 5 ):
    print('progress: ', index)
    candidate_list = []
    for component in range( len(input_ids_corss_component_list) ):
        # start = starting_batch_input_len_cross_comp_lst[component][index]
        # the_tensor = input_ids_corss_component_list[component][index][start:, :].transpose(0 , 1)
        # candidate_list.extend( tokenizer.batch_decode( the_tensor , skip_special_tokens=True ) )
        candidate_list.extend(input_ids_corss_component_list[component][index:index+5])
    candidate_list_1=[]
    for c in candidate_list:
        candidate_list_1.append(post_process_get_sql_from_gentext(c))
    sorted_queries, _  = sql_scoring.sort_queries(candidate_list_1)
    
    final_sorted_candidates.extend(sorted_queries)
with open(output_file , 'wb') as f:
    pkl.dump(final_sorted_candidates , f)
# Out:
# progress:  0
# progress:  5
# progress:  10
# progress:  15
# progress:  20
# progress:  25
# progress:  30
# progress:  35
# progress:  40
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7f3c78835670>>
# Traceback (most recent call last):
#   File "/home/yadegari/miniconda3/envs/yadegari_cpu/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
# progress:  45
# progress:  50
# progress:  55
# progress:  60
# progress:  65
# progress:  70
# progress:  75
# progress:  80
# progress:  85
# progress:  90
# progress:  95
# progress:  100
# progress:  105
# progress:  110
# progress:  115
# progress:  120
# progress:  125
# progress:  130
# progress:  135
# progress:  140
# progress:  145
# progress:  150
# progress:  155
# progress:  160
# progress:  165
# progress:  170
# progress:  175
# progress:  180
# progress:  185
# progress:  190
# progress:  195
# progress:  200
# progress:  205
# progress:  210
# progress:  215
# progress:  220
# progress:  225
# progress:  230
# progress:  235
# progress:  240
# progress:  245
# progress:  250
# progress:  255
# progress:  260
# progress:  265
# progress:  270
# progress:  275
# progress:  280
# progress:  285
# progress:  290
# progress:  295
# progress:  300
# progress:  305
# progress:  310
# progress:  315
# progress:  320
# progress:  325
# progress:  330
# progress:  335
# progress:  340
# progress:  345
# progress:  350
# progress:  355
# progress:  360
# progress:  365
# progress:  370
# progress:  375
# progress:  380
# progress:  385
# progress:  390
# progress:  395
# progress:  400
# progress:  405
# progress:  410
# progress:  415
# progress:  420
# progress:  425
# progress:  430
# progress:  435
# progress:  440
# progress:  445
# progress:  450
# progress:  455
# progress:  460
# progress:  465
# progress:  470
# progress:  475
# progress:  480
# progress:  485
# progress:  490
# progress:  495
# progress:  500
# progress:  505
# progress:  510
# progress:  515
# progress:  520
# progress:  525
# progress:  530
# progress:  535
# progress:  540
# progress:  545
# progress:  550
# progress:  555
# progress:  560
# progress:  565
# progress:  570
# progress:  575
# progress:  580
# progress:  585
# progress:  590
# progress:  595
# progress:  600
# progress:  605
# progress:  610
# progress:  615
# progress:  620
# progress:  625
# progress:  630
# progress:  635
# progress:  640
# progress:  645
# progress:  650
# progress:  655
# progress:  660
# progress:  665
# progress:  670
# progress:  675
# progress:  680
# progress:  685
# progress:  690
# progress:  695
# progress:  700
# progress:  705
# progress:  710
# progress:  715
# progress:  720
# progress:  725
# progress:  730
# progress:  735
# progress:  740
# progress:  745
# progress:  750
# progress:  755
# progress:  760
# progress:  765
# progress:  770
# progress:  775
# progress:  780
# progress:  785
# progress:  790
# progress:  795
# progress:  800
# progress:  805
# progress:  810
# progress:  815
# progress:  820
# progress:  825
# progress:  830
# progress:  835
# progress:  840
# progress:  845
# progress:  850
# progress:  855
# progress:  860
# progress:  865
# progress:  870
# progress:  875
# progress:  880
# progress:  885
# progress:  890
# progress:  895
# progress:  900
# progress:  905
# progress:  910
HERE cards.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 15, query:SELECT bordercolor FROM cards WHERE name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 17, query:SELECT bordercolor FROM cards WHERE name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 19, query:SELECT bordercolor FROM cards WHERE name = 'Ancestor'\''s Chosen' ;
# One of the queries are invalid: index = 20, query:SELECT bordercolor FROM cards WHERE name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 21, query:SELECT bordercolor FROM cards WHERE name = 'Ancestor\'s Chosen'
# progress:  1795
# One of the queries are invalid: index = 0, query:SELECT cards.originaltype FROM cards WHERE cards.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 1, query:SELECT cards.originaltype FROM cards WHERE cards.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 4, query:SELECT originaltype FROM cards WHERE name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 5, query:SELECT originaltype FROM cards WHERE name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 6, query:SELECT cards.originaltype FROM cards WHERE cards.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 7, query:SELECT originaltype FROM cards WHERE name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 8, query:SELECT cards.originaltype FROM cards WHERE cards.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 10, query:SELECT originaltype FROM cards WHERE name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 11, query:SELECT cards.originaltype FROM cards WHERE cards.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 12, query:SELECT originaltype FROM cards WHERE name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 15, query:SELECT cards.originaltype FROM cards WHERE cards.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 16, query:SELECT cards.originaltype FROM cards WHERE cards.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 19, query:SELECT originaltype FROM cards WHERE name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 20, query:SELECT originaltype FROM cards WHERE name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 21, query:SELECT cards.originaltype FROM cards WHERE cards.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 22, query:SELECT originaltype FROM cards WHERE name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 23, query:SELECT cards.originaltype FROM cards WHERE cards.name = 'Ancestor\'s Chosen'
# progress:  1800
# progress:  1805
# progress:  1810
# progress:  1815
# progress:  1820
# progress:  1825
# progress:  1830
# progress:  1835
# progress:  1840
# progress:  1845
# progress:  1850
# progress:  1855
# progress:  1860
# progress:  1865
# progress:  1870
# progress:  1875
# progress:  1880
# progress:  1885
# progress:  1890
# progress:  1895
# progress:  1900
# progress:  1905
# progress:  1910
# progress:  1915
# progress:  1920
# progress:  1925
# progress:  1930
# progress:  1935
# progress:  1940
# progress:  1945
# progress:  1950
# progress:  1955
# progress:  1960
# progress:  1965
# progress:  1970
# progress:  1975
# progress:  1980
# progress:  1985
# progress:  1990
# progress:  1995
# progress:  2000
# progress:  2005
# progress:  2010
# progress:  2015
# progress:  2020
# progress:  2025
# progress:  2030
# progress:  2035
# progress:  2040
# progress:  2045
# progress:  2050
# progress:  2055
# progress:  2060
# progress:  2065
# progress:  2070
# progress:  2075
# progress:  2080
# progress:  2085
# progress:  2090
# progress:  2095
# progress:  2100
# progress:  2105
# progress:  2110
# progress:  2115
# progress:  2120
# progress:  2125
# progress:  2130
# progress:  2135
# progress:  2140
# progress:  2145
# progress:  2150
# progress:  2155
# progress:  2160
# progress:  2165
# progress:  2170
# progress:  2175
# progress:  2180
# progress:  2185
# progress:  2190
# progress:  2195
# progress:  2200
# progress:  2205
# progress:  2210
# progress:  2215
# progress:  2220
# progress:  2225
# progress:  2230
# progress:  2235
# progress:  2240
# progress:  2245
# progress:  2250
# progress:  2255
# progress:  2260
# progress:  2265
# One of the queries are invalid: index = 0, query:SELECT manacost FROM cards WHERE name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 1, query:SELECT manacost FROM cards WHERE name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 3, query:SELECT manacost FROM cards WHERE name = 'Ancestor's Chosen' ;
# One of the queries are invalid: index = 5, query:SELECT manacost FROM cards WHERE name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 6, query:SELECT manacost FROM cards WHERE name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 10, query:SELECT manacost FROM cards WHERE name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 11, query:SELECT manacost FROM cards WHERE name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 14, query:SELECT manacost FROM cards WHERE name = 'Ancestor'\''s Chosen'
# One of the queries are invalid: index = 15, query:SELECT manacost FROM cards WHERE name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 16, query:SELECT manacost FROM cards WHERE name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 22, query:SELECT manacost FROM cards WHERE name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 23, query:SELECT manacost FROM cards WHERE name = 'Ancestor\'s Chosen'
# progress:  2270
# progress:  2275
# progress:  2280
# progress:  2285
# progress:  2290
# progress:  2295
# progress:  2300
# progress:  2305
# progress:  2310
# One of the queries are invalid: index = 0, query:SELECT T2.translation FROM cards AS T1 JOIN set_translations AS T2 ON T1.setcode = T2.setcode WHERE T1.name = 'Ancestor\'s Chosen' AND T2.language = 'Italian'
# One of the queries are invalid: index = 3, query:SELECT T3.translation FROM cards AS T1 JOIN sets AS T2 ON T1.setcode = T2.code JOIN set_translations AS T3 ON T2.code = T3.setcode WHERE T1.name = 'Ancestor\'s Chosen' AND T3.language = 'Italian'
# One of the queries are invalid: index = 4, query:SELECT T3.translation FROM cards AS T1 JOIN sets AS T2 ON T1.setcode = T2.code JOIN set_translations AS T3 ON T2.code = T3.setcode WHERE T3.language = 'Italian' AND T1.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 5, query:SELECT T2.translation FROM cards AS T1 JOIN set_translations AS T2 ON T1.setcode = T2.setcode WHERE T1.name = 'Ancestor\'s Chosen' AND T2.language = 'Italian'
# One of the queries are invalid: index = 6, query:SELECT T2.translation FROM cards AS T1 JOIN set_translations AS T2 ON T1.setcode = T2.setcode WHERE T1.name = 'Ancestor\'s Chosen' AND T2.language = 'Italian' ;
# One of the queries are invalid: index = 7, query:SELECT DISTINCT T2.translation FROM cards AS T1 JOIN set_translations AS T2 ON T1.setcode = T2.setcode WHERE T1.name = 'Ancestor\'s Chosen' AND T2.language = 'Italian'
# One of the queries are invalid: index = 8, query:SELECT T2.translation FROM cards AS T1 JOIN set_translations AS T2 ON T1.setcode = T2.setcode WHERE T2.language = 'Italian' AND T1.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 9, query:SELECT T1.translation FROM set_translations AS T1 JOIN sets AS T2 ON T1.setcode = T2.code JOIN cards AS T3 ON T2.code = T3.setcode WHERE T3.name = 'Ancestor\'s Chosen' AND T1.language = 'Italian'
# One of the queries are invalid: index = 10, query:SELECT T2.translation FROM cards AS T1 JOIN set_translations AS T2 ON T1.setcode = T2.setcode WHERE T1.name = 'Ancestor\'s Chosen' AND T2.language = 'Italian'
# One of the queries are invalid: index = 12, query:SELECT T2.translation FROM cards AS T1 JOIN set_translations AS T2 ON T1.setcode = T2.setcode WHERE T1.name = 'Ancestor\'s Chosen' AND T2.language = 'Italian' ;
# One of the queries are invalid: index = 14, query:SELECT set_translations.translation FROM set_translations INNER JOIN sets ON set_translations.setcode = sets.code INNER JOIN cards ON sets.code = cards.setcode WHERE cards.name = 'Ancestor\'s Chosen' AND set_translations.language = 'Italian' ;
# One of the queries are invalid: index = 15, query:SELECT T2.translation FROM cards AS T1 JOIN set_translations AS T2 ON T1.setcode = T2.setcode WHERE T1.name = 'Ancestor\'s Chosen' AND T2.language = 'Italian'
# One of the queries are invalid: index = 16, query:SELECT T2.translation FROM cards AS T1 JOIN set_translations AS T2 ON T1.setcode = T2.setcode WHERE T1.name = 'Ancestor\'s Chosen' AND T2.language = 'Italian' ;
# One of the queries are invalid: index = 18, query:SELECT set_translations.translation FROM set_translations INNER JOIN sets ON set_translations.setcode = sets.code INNER JOIN cards ON sets.code = cards.setcode WHERE cards.name = 'Ancestor\'s Chosen' AND set_translations.language = 'Italian'
# One of the queries are invalid: index = 19, query:SELECT set_translations.translation FROM set_translations INNER JOIN sets ON set_translations.setcode = sets.code INNER JOIN cards ON sets.code = cards.setcode WHERE cards.name = 'Ancestor\'s Chosen' AND set_translations.language = 'Italian' ;
# One of the queries are invalid: index = 20, query:SELECT T2.translation FROM cards AS T1 JOIN set_translations AS T2 ON T1.setcode = T2.setcode WHERE T1.name = 'Ancestor\'s Chosen' AND T2.language = 'Italian'
# One of the queries are invalid: index = 23, query:SELECT T1.translation FROM set_translations AS T1 JOIN sets AS T2 ON T1.setcode = T2.code JOIN cards AS T3 ON T2.code = T3.setcode WHERE T3.name = 'Ancestor\'s Chosen' AND T1.language = 'Italian'
# progress:  2315
# progress:  2320
# progress:  2325
# One of the queries are invalid: index = 5, query:SELECT CASE WHEN foreign_data.language = 'Korean' THEN 'YES' ELSE 'NO' END FROM foreign_data INNER JOIN cards ON foreign_data.uuid = cards.uuid WHERE cards.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 7, query:SELECT CASE WHEN foreign_data.language = 'Korean' THEN 'YES' ELSE 'NO' END FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE cards.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 14, query:SELECT CASE WHEN count(foreign_data.uuid) > 0 THEN 'YES' ELSE 'NO' END AS yorn FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE cards.name = 'Ancestor\'s Chosen' AND foreign_data.language = 'Korean' ;
# One of the queries are invalid: index = 17, query:SELECT T1.name FROM sets AS T1 JOIN set_translations AS T2 ON T1.code = T2.setcode JOIN cards AS T3 ON T1.code = T3.setcode WHERE T3.name = 'Ancestor\'s Chosen' AND T2.language = 'Korean'
# One of the queries are invalid: index = 18, query:SELECT T1.language FROM set_translations AS T1 JOIN cards AS T2 ON T1.setcode = T2.setcode WHERE T2.name = 'Ancestor\'s Chosen' AND T1.language = 'Korean'
# One of the queries are invalid: index = 21, query:SELECT foreign_data.name FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE cards.name = 'Ancestor\'s Chosen' AND foreign_data.language = 'Korean' ;
# progress:  2330
# progress:  2335
# progress:  2340
# progress:  2345
# progress:  2350
# One of the queries are invalid: index = 0, query:SELECT T2.releasedate FROM cards AS T1 JOIN sets AS T2 ON T1.setcode = T2.code WHERE T1.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 1, query:SELECT T1.releasedate FROM sets AS T1 JOIN cards AS T2 ON T1.code = T2.setcode WHERE T2.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 2, query:SELECT T1.releasedate FROM sets AS T1 JOIN cards AS T2 ON T1.code = T2.setcode WHERE T2.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 3, query:SELECT T2.releasedate FROM cards AS T1 JOIN sets AS T2 ON T1.setcode = T2.code WHERE T1.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 4, query:SELECT T1.releasedate FROM sets AS T1 JOIN cards AS T2 ON T1.id = T2.setid WHERE T2.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 5, query:SELECT T1.releasedate FROM sets AS T1 JOIN cards AS T2 ON T1.code = T2.setcode WHERE T2.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 6, query:SELECT T1.releasedate FROM sets AS T1 JOIN cards AS T2 ON T1.code = T2.setcode WHERE T2.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 7, query:SELECT T2.releasedate FROM cards AS T1 JOIN sets AS T2 ON T1.setcode = T2.code WHERE T1.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 8, query:SELECT T2.releasedate FROM cards AS T1 JOIN sets AS T2 ON T1.setcode = T2.code WHERE T1.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 9, query:SELECT T1.releasedate FROM sets AS T1 JOIN cards AS T2 ON T1.id = T2.setid WHERE T2.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 10, query:SELECT T2.releasedate FROM cards AS T1 JOIN sets AS T2 ON T1.setcode = T2.code WHERE T1.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 11, query:SELECT T1.releasedate FROM sets AS T1 JOIN cards AS T2 ON T1.code = T2.setcode WHERE T2.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 12, query:SELECT T2.releasedate FROM cards AS T1 JOIN sets AS T2 ON T1.setcode = T2.code WHERE T1.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 13, query:SELECT T1.releasedate FROM sets AS T1 INNER JOIN cards AS T2 ON T1.code = T2.setcode WHERE T2.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 14, query:SELECT T1.releasedate FROM sets AS T1 INNER JOIN cards AS T2 ON T1.code = T2.setcode WHERE T2.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 15, query:SELECT T1.releasedate FROM sets AS T1 INNER JOIN cards AS T2 ON T1.code = T2.setcode WHERE T2.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 16, query:SELECT T1.releasedate FROM sets AS T1 INNER JOIN cards AS T2 ON T1.code = T2.setcode WHERE T2.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 17, query:SELECT T2.releasedate FROM cards AS T1 INNER JOIN sets AS T2 ON T1.setcode = T2.code WHERE T1.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 18, query:SELECT T1.releasedate FROM sets AS T1 INNER JOIN cards AS T2 ON T2.setcode = T1.code WHERE T2.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 19, query:SELECT T2.releasedate FROM cards AS T1 INNER JOIN sets AS T2 ON T1.setcode = T2.code WHERE T1.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 20, query:SELECT T1.releasedate FROM sets AS T1 JOIN cards AS T2 ON T1.code = T2.setcode WHERE T2.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 21, query:SELECT T2.releasedate FROM cards AS T1 JOIN sets AS T2 ON T1.setcode = T2.code WHERE T1.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 22, query:SELECT T1.releasedate FROM sets AS T1 JOIN cards AS T2 ON T1.code = T2.setcode WHERE T2.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 23, query:SELECT sets.releasedate FROM sets INNER JOIN cards ON sets.code = cards.setcode WHERE cards.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 24, query:SELECT T2.releasedate FROM cards AS T1 JOIN sets AS T2 ON T1.setcode = T2.code WHERE T1.name = 'Ancestor\'s Chosen' AND T1.facename = 'Release' ;
# progress:  2355
# progress:  2360
# progress:  2365
# progress:  2370
# progress:  2375
# progress:  2380
# progress:  2385
# progress:  2390
# progress:  2395
# progress:  2400
# One of the queries are invalid: index = 3, query:SELECT foreign_data.flavortext FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE cards.name = 'Ancestor\'s Chosen' AND foreign_data.language = 'Italian'
# One of the queries are invalid: index = 4, query:SELECT foreign_data.flavortext FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE cards.name = 'Ancestor\'s Chosen' AND foreign_data.language = 'Italian' ;
# One of the queries are invalid: index = 5, query:SELECT T1.flavortext FROM foreign_data AS T1 JOIN cards AS T2 ON T1.uuid = T2.uuid WHERE T1.language = 'Italian' AND T2.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 7, query:SELECT T1.flavortext FROM foreign_data AS T1 JOIN cards AS T2 ON T1.uuid = T2.uuid WHERE T2.name = 'Ancestor\'s Chosen' AND T1.language = 'Italian'
# One of the queries are invalid: index = 8, query:SELECT foreign_data.flavortext FROM foreign_data INNER JOIN cards ON foreign_data.uuid = cards.uuid WHERE foreign_data.language = 'Italian' AND cards.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 9, query:SELECT foreign_data.flavortext FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE foreign_data.language = 'Italian' AND cards.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 10, query:SELECT foreign_data.flavortext FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE cards.name = 'Ancestor\'s Chosen' AND foreign_data.language = 'Italian' ;
# One of the queries are invalid: index = 11, query:SELECT foreign_data.flavortext FROM foreign_data INNER JOIN cards ON foreign_data.uuid = cards.uuid WHERE foreign_data.language = 'Italian' AND cards.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 12, query:SELECT foreign_data.flavortext FROM foreign_data INNER JOIN cards ON foreign_data.uuid = cards.uuid WHERE cards.name = 'Ancestor\'s Chosen' AND foreign_data.language = 'Italian' ;
# One of the queries are invalid: index = 13, query:SELECT foreign_data.flavortext FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE foreign_data.language = 'Italian' AND cards.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 14, query:SELECT T2.flavortext FROM cards AS T1 JOIN foreign_data AS T2 ON T1.uuid = T2.uuid WHERE T1.name = 'Ancestor\'s Chosen' AND T2.language = 'Italian'
# One of the queries are invalid: index = 15, query:SELECT foreign_data.flavortext FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE cards.name = 'Ancestor\'s Chosen' AND foreign_data.language = 'Italian' ;
# One of the queries are invalid: index = 16, query:SELECT foreign_data.flavortext FROM foreign_data INNER JOIN cards ON foreign_data.uuid = cards.uuid WHERE cards.name = 'Ancestor\'s Chosen' AND foreign_data.language = 'Italian' ;
# One of the queries are invalid: index = 17, query:SELECT foreign_data.flavortext FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE foreign_data.language = 'Italian' AND cards.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 18, query:SELECT foreign_data.flavortext FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE cards.name = 'Ancestor\'s Chosen' AND foreign_data.language = 'Italian'
# One of the queries are invalid: index = 19, query:SELECT T2.flavortext FROM cards AS T1 JOIN foreign_data AS T2 ON T1.uuid = T2.uuid WHERE T1.name = 'Ancestor\'s Chosen' AND T2.language = 'Italian' ;
# One of the queries are invalid: index = 20, query:SELECT foreign_data.flavortext FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE cards.name = 'Ancestor\'s Chosen' AND foreign_data.language = 'Italian' ;
# One of the queries are invalid: index = 22, query:SELECT foreign_data.flavortext FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE cards.name = 'Ancestor\'s Chosen' AND foreign_data.language = 'Italian'
# progress:  2405
# One of the queries are invalid: index = 0, query:SELECT T1.language FROM foreign_data AS T1 JOIN cards AS T2 ON T1.uuid = T2.uuid WHERE T2.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 1, query:SELECT T2.language FROM cards AS T1 JOIN foreign_data AS T2 ON T1.uuid = T2.uuid WHERE T1.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 2, query:SELECT foreign_data.language FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE cards.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 3, query:SELECT T2.language FROM cards AS T1 JOIN foreign_data AS T2 ON T1.uuid = T2.uuid WHERE T1.name = 'Ancestor\'s Chosen' GROUP BY T2.language
# One of the queries are invalid: index = 4, query:SELECT foreign_data.language FROM foreign_data INNER JOIN cards ON foreign_data.uuid = cards.uuid WHERE cards.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 7, query:SELECT T2.language FROM cards AS T1 JOIN foreign_data AS T2 ON T1.uuid = T2.uuid WHERE T1.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 8, query:SELECT T1.language FROM foreign_data AS T1 JOIN cards AS T2 ON T1.uuid = T2.uuid WHERE T2.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 10, query:SELECT foreign_data.language FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE cards.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 11, query:SELECT T2.language FROM cards AS T1 JOIN foreign_data AS T2 ON T1.uuid = T2.uuid WHERE T1.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 12, query:SELECT T1.language FROM foreign_data AS T1 JOIN cards AS T2 ON T1.uuid = T2.uuid WHERE T2.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 13, query:SELECT DISTINCT foreign_data.language FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE cards.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 14, query:SELECT foreign_data.language FROM foreign_data INNER JOIN cards ON foreign_data.uuid = cards.uuid WHERE cards.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 15, query:SELECT T1.language FROM foreign_data AS T1 JOIN cards AS T2 ON T1.uuid = T2.uuid WHERE T2.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 16, query:SELECT T2.language FROM cards AS T1 JOIN foreign_data AS T2 ON T1.uuid = T2.uuid WHERE T1.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 17, query:SELECT DISTINCT T2.language FROM cards AS T1 JOIN foreign_data AS T2 ON T1.uuid = T2.uuid WHERE T1.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 18, query:SELECT T2.language FROM cards AS T1 JOIN foreign_data AS T2 ON T1.uuid = T2.uuid WHERE T1.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 19, query:SELECT DISTINCT T1.language FROM foreign_data AS T1 JOIN cards AS T2 ON T1.uuid = T2.uuid WHERE T2.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 20, query:SELECT foreign_data.language FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE cards.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 21, query:SELECT foreign_data.language FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE cards.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 22, query:SELECT foreign_data.language FROM foreign_data INNER JOIN cards ON foreign_data.uuid = cards.uuid WHERE cards.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 23, query:SELECT foreign_data.language FROM foreign_data INNER JOIN cards ON foreign_data.uuid = cards.uuid WHERE cards.name = 'Ancestor\'s Chosen'
# progress:  2410
# One of the queries are invalid: index = 0, query:SELECT foreign_data.type FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE cards.name = 'Ancestor\'s Chosen' AND foreign_data.language = 'German'
# One of the queries are invalid: index = 1, query:SELECT foreign_data.type FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE cards.name = 'Ancestor\'s Chosen' AND foreign_data.language = 'German' ;
# One of the queries are invalid: index = 3, query:SELECT T2.type FROM cards AS T1 JOIN foreign_data AS T2 ON T1.uuid = T2.uuid WHERE T1.name = 'Ancestor\'s Chosen' AND T2.language = 'German'
# One of the queries are invalid: index = 7, query:SELECT T2.type FROM cards AS T1 JOIN foreign_data AS T2 ON T1.uuid = T2.uuid WHERE T1.name = 'Ancestor\'s Chosen' AND T2.language = 'German'
# One of the queries are invalid: index = 8, query:SELECT foreign_data.type FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE cards.name = 'Ancestor\'s Chosen' AND foreign_data.language = 'German'
# One of the queries are invalid: index = 9, query:SELECT foreign_data.type FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE cards.name = 'Ancestor\'s Chosen' AND foreign_data.language = 'German' ;
# One of the queries are invalid: index = 10, query:SELECT foreign_data.type FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE cards.name = 'Ancestor\'s Chosen' AND foreign_data.language = 'German' ;
# One of the queries are invalid: index = 11, query:SELECT foreign_data.type FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE foreign_data.language = 'German' AND cards.name = 'Ancestor\'s Chosen' ;
# One of the queries are invalid: index = 13, query:SELECT foreign_data.type FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE cards.name = 'Ancestor\'s Chosen' AND foreign_data.language = 'German'
# One of the queries are invalid: index = 14, query:SELECT foreign_data.type FROM foreign_data INNER JOIN cards ON foreign_data.uuid = cards.uuid WHERE cards.name = 'Ancestor\'s Chosen' AND foreign_data.language = 'German' ;
# One of the queries are invalid: index = 15, query:SELECT T2.type FROM cards AS T1 JOIN foreign_data AS T2 ON T1.uuid = T2.uuid WHERE T1.name = 'Ancestor\'s Chosen' AND T2.language = 'German'
# One of the queries are invalid: index = 16, query:SELECT T1.type FROM foreign_data AS T1 JOIN cards AS T2 ON T1.uuid = T2.uuid WHERE T2.name = 'Ancestor\'s Chosen' AND T1.language = 'German'
# One of the queries are invalid: index = 18, query:SELECT T2.type FROM cards AS T1 JOIN foreign_data AS T2 ON T1.uuid = T2.uuid WHERE T1.name = 'Ancestor\'s Chosen' AND T2.language = 'German' ;
# One of the queries are invalid: index = 19, query:SELECT T2.type FROM cards AS T1 JOIN foreign_data AS T2 ON T1.uuid = T2.uuid WHERE T2.language = 'German' AND T1.name = 'Ancestor\'s Chosen'
# One of the queries are invalid: index = 20, query:SELECT foreign_data.type FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE cards.name = 'Ancestor\'s Chosen' AND foreign_data.language = 'German'
# One of the queries are invalid: index = 21, query:SELECT foreign_data.type FROM cards INNER JOIN foreign_data ON cards.uuid = foreign_data.uuid WHERE cards.name = 'Ancestor\'s Chosen' AND foreign_data.language = 'German' ;
# One of the queries are invalid: index = 22, query:SELECT foreign_data.type FROM foreign_data INNER JOIN cards ON foreign_data.uuid = cards.uuid WHERE cards.name = 'Ancestor\'s Chosen' AND foreign_data.language = 'German'
# One of the queries are invalid: index = 24, query:SELECT foreign_data.type FROM foreign_data INNER JOIN cards ON foreign_data.uuid = cards.uuid WHERE cards.name = 'Ancestor\'s Chosen' AND foreign_data.language = 'German' ;
# progress:  2415
# progress:  2420
# progress:  2425
# progress:  2430
# progress:  2435
# progress:  2440
# progress:  2445
# progress:  2450
# progress:  2455
# progress:  2460
# progress:  2465
# progress:  2470
# progress:  2475
# progress:  2480
# progress:  2485
# progress:  2490
# progress:  2495
# progress:  2500
# progress:  2505
# One of the queries are invalid: index = 3, query:SELECT T2.name FROM sets AS T1 JOIN cards AS T2 ON T1.code = T2.setcode WHERE T1.name = 'Journey into Nyx Hero\'s Path' ORDER BY T2.convertedmanacost DESC LIMIT 1
# One of the queries are invalid: index = 4, query:SELECT T1.name FROM cards AS T1 JOIN set_translations AS T2 ON T1.uuid = T2.uuid WHERE T2.translation = 'Journey into Nyx Hero\'s Path' ORDER BY T1.convertedmanacost DESC LIMIT 1
# One of the queries are invalid: index = 7, query:SELECT T2.name FROM sets AS T1 JOIN cards AS T2 ON T1.code = T2.setcode WHERE T1.name = 'Journey into Nyx Hero\'s Path' ORDER BY T2.convertedmanacost DESC LIMIT 1
# One of the queries are invalid: index = 8, query:SELECT T1.name FROM cards AS T1 JOIN set_cards AS T2 ON T1.id = T2.card_id JOIN sets AS T3 ON T2.set_id = T3.id WHERE T3.name = 'Journey into Nyx Hero\'s Path' ORDER BY T1.convertedmanacost DESC LIMIT 1
# One of the queries are invalid: index = 10, query:SELECT T2.name FROM set_translations AS T1 JOIN cards AS T2 ON T1.setcode = T2.setcode WHERE T1.translation = 'Journey into Nyx Hero\'s Path' ORDER BY T2.convertedmanacost DESC LIMIT 1
# One of the queries are invalid: index = 11, query:SELECT T1.name FROM cards AS T1 JOIN set_translations AS T2 ON T1.uuid = T2.uuid WHERE T2.translation = 'Journey into Nyx Hero\'s Path' ORDER BY T1.convertedmanacost DESC LIMIT 1
# One of the queries are invalid: index = 12, query:SELECT cards.name FROM cards INNER JOIN set_translations ON cards.uuid = set_translations.uuid WHERE set_translations.translation = 'Journey into Nyx Hero\'s Path' ORDER BY cards.convertedmanacost DESC LIMIT 1 ;
# One of the queries are invalid: index = 14, query:SELECT cards.name FROM cards INNER JOIN set_translations ON cards.uuid = set_translations.uuid WHERE set_translations.translation = 'Journey into Nyx Hero\'s Path' ORDER BY cards.convertedmanacost DESC LIMIT 1
# One of the queries are invalid: index = 17, query:SELECT T1.name FROM cards AS T1 JOIN set_translations AS T2 ON T1.uuid = T2.uuid WHERE T2.translation = 'Journey into Nyx Hero\'s Path' ORDER BY T1.convertedmanacost DESC LIMIT 1
# One of the queries are invalid: index = 18, query:SELECT T2.name FROM sets AS T1 JOIN cards AS T2 ON T1.code = T2.setcode WHERE T1.name = 'Journey into Nyx Hero\'s Path' ORDER BY T2.convertedmanacost DESC LIMIT 1
# One of the queries are invalid: index =
# One of the queries are invalid: index = 0, query:SELECT count(player_name) FROM player WHERE birthday LIKE '1991%' OR birthday LIKE '1992%' OR birthday LIKE '1993%' OR birthday LIKE '1994%' OR birthday LIKE '1995%' OR birthday LIKE '1996%' OR birthday LIKE '1997%' OR birthday LIKE '1998%' OR birthday LIKE '1999%' OR birthday LIKE '2000%' OR birthday LIKE '2001%' OR birthday LIKE '2002%' OR birthday LIKE '2003%' OR birthday LIKE '2004%' OR birthday LIKE '2005%' OR birthday LIKE '2006%' OR birthday LIKE '2007%' OR birthday LIKE '2008%' OR birthday LIKE '2009%' OR birthday LIKE '2010%' OR birthday LIKE '2011%' OR birthday LIKE '2012%' OR birthday LIKE '2013%' OR birthday LIKE '2014%' OR birthday LIKE '2015%' OR birthday LIKE '2016%' OR birthday LIKE '2017%' OR birthday LIKE '2018%' OR birthday LIKE '2019%' OR birthday LIKE '2020%' OR birthday LIKE '2021%' OR birthday LIKE '2022%' OR birthday LIKE '20
# progress:  5305
# progress:  5310
# progress:  5315
# progress:  5320
# progress:  5325
# progress:  5330
# progress:  5335
# progress:  5340
# progress:  5345
# progress:  5350
# progress:  5355
# progress:  5360
# progress:  5365
# progress:  5370
# progress:  5375
# progress:  5380
# progress:  5385
# progress:  5390
# progress:  5395
# progress:  5400
# progress:  5405
# progress:  5410
# progress:  5415
# progress:  5420
# progress:  5425
# progress:  5430
# progress:  5435
# progress:  5440
# progress:  5445
# progress:  5450
# progress:  5455
# progress:  5460
# progress:  5465
# progress:  5470
# progress:  5475
# progress:  5480
# progress:  5485
# progress:  5490
# progress:  5495
# progress:  5500
# progress:  5505
# progress:  5510
# progress:  5515
# progress:  5520
# progress:  5525
# progress:  5530
# progress:  5535
# progress:  5540
# progress:  5545
# progress:  5550
# progress:  5555
# progress:  5560
# progress:  5565
# progress:  5570
# progress:  5575
# progress:  5580
# progress:  5585
# progress:  5590
# progress:  5595
# One of the queries are invalid: index = 17, query:SELECT count(*) FROM player AS T1 INNER JOIN match AS T2 ON T1.player_api_id = T2.home_player_1 WHERE T1.player_name = 'Aaron Lennon' UNION SELECT count(*) FROM player AS T1 INNER JOIN match AS T2 ON T1.player_api_id = T2.home_player_2 WHERE T1.player_name = 'Aaron Lennon' UNION SELECT count(*) FROM player AS T1 INNER JOIN match AS T2 ON T1.player_api_id = T2.home_player_3 WHERE T1.player_name = 'Aaron Lennon' UNION SELECT count(*) FROM player AS T1 INNER JOIN match AS T2 ON T1.player_api_id = T2.home_player_4 WHERE T1.player_name = 'Aaron Lennon' UNION SELECT count(*) FROM player AS T1 INNER JOIN match AS T2 ON T1.player_api_id = T2.home_player_5 WHERE T1.player_name = 'Aaron Lennon' UNION SELECT count(*) FROM player AS T1 INNER JOIN match AS T2 ON T1.player_api_id = T2.home_player_6 WHERE T1.player_name = 'Aaron Lennon' UNION SELECT count(*) FROM player AS T1 INNER JOIN match AS T2 ON T1.player_api_id = T2.home_player_7 WHERE T1.player_name = 'Aaron Lennon' UNION SELECT count(*) FROM player AS T1 INNER JOIN match AS T2 ON T1.player_api_id = T2.home_player_8 WHERE T1.player_name = 'Aaron
# progress:  5600
# progress:  5605
# progress:  5610
# progress:  5615
# progress:  5620
# progress:  5625
# progress:  5630
# progress:  5635
# progress:  5640
# progress:  5645
# progress:  5650
# progress:  5655
# progress:  5660
# progress:  5665
# progress:  5670
# progress:  5675
# progress:  5680
# progress:  5685
# progress:  5690
# progress:  5695
# progress:  5700
# progress:  5705
# progress:  5710
# progress:  5715
# progress:  5720
# progress:  5725
# progress:  5730
# progress:  5735
# progress:  5740
# progress:  5745
# progress:  5750
# progress:  5755
# progress:  5760
# progress:  5765
# progress:  5770
# progress:  5775
# progress:  5780
# progress:  5785
# progress:  5790
# progress:  5795
# progress:  5800
# progress:  5805
# progress:  5810
# progress:  5815
# progress:  5820
# progress:  5825
# progress:  5830
# progress:  5835
# progress:  5840
# progress:  5845
# progress:  5850
# progress:  5855
# progress:  5860
# progress:  5865
# progress:  5870
# progress:  5875
# progress:  5880
# progress:  5885
# progress:  5890
# progress:  5895
# progress:  5900
# progress:  5905
# progress:  5910
# progress:  5915
# progress:  5920
# progress:  5925
# progress:  5930
# progress:  5935
# progress:  5940
# progress:  5945
# progress:  5950
# progress:  5955
# progress:  5960
# progress:  5965
# progress:  5970
# progress:  5975
# progress:  5980
# progress:  5985
# progress:  5990
# progress:  5995
# progress:  6000
# progress:  6005
# progress:  6010
# progress:  6015
# progress:  6020
# progress:  6025
# progress:  6030
# progress:  6035
# progress:  6040
# progress:  6045
# progress:  6050
# progress:  6055
# progress:  6060
# progress:  6065
# progress:  6070
# progress:  6075
# progress:  6080
# progress:  6085
# progress:  6090
# progress:  6095
# progress:  6100
# progress:  6105
# progress:  6110
# progress:  6115
# progress:  6120
# progress:  6125
# progress:  6130
# progress:  6135
# progress:  6140
# progress:  6145
# progress:  6150
# progress:  6155
# progress:  6160
# progress:  6165
# progress:  6170
# progress:  6175
# progress:  6180
# progress:  6185
# progress:  6190
# progress:  6195
# progress:  6200
# progress:  6205
# progress:  6210
# progress:  6215
# progress:  6220
# progress:  6225
# progress:  6230
# progress:  6235
# progress:  6240
# progress:  6245
# progress:  6250
# progress:  6255
# progress:  6260
# progress:  6265
# progress:  6270
# progress:  6275
# progress:  6280
# progress:  6285
# progress:  6290
# progress:  6295
# progress:  6300
# progress:  6305
# progress:  6310
# progress:  6315
# progress:  6320
# progress:  6325
# progress:  6330
# progress:  6335
# progress:  6340
# progress:  6345
# progress:  6350
# progress:  6355
# progress:  6360
# progress:  6365
# progress:  6370
# progress:  6375
# progress:  6380
# progress:  6385
# progress:  6390
# progress:  6395
# progress:  6400
# progress:  6405
# progress:  6410
# progress:  6415
# progress:  6420
# progress:  6425
# progress:  6430
# progress:  6435
# progress:  6440
# progress:  6445
# progress:  6450
# progress:  6455
# progress:  6460
# progress:  6465
# progress:  6470
# progress:  6475
# progress:  6480
# progress:  6485
# progress:  6490
# progress:  6495
# progress:  6500
# progress:  6505
# progress:  6510
# progress:  6515
# progress:  6520
# progress:  6525
# progress:  6530
# progress:  6535
# progress:  6540
# progress:  6545
# progress:  6550
# progress:  6555
# progress:  6560
# progress:  6565
# progress:  6570
# progress:  6575
# One of the queries are invalid: index = 6, query:SELECT count(attendance.link_to_member) FROM attendance INNER JOIN event ON attendance.link_to_event = event.event_id WHERE event.event_name = 'Women\'s Soccer' ;
# One of the queries are invalid: index = 21, query:SELECT count(attendance.link_to_member) FROM attendance INNER JOIN event ON attendance.link_to_event = event.event_id WHERE event.event_name = 'Women\'s Soccer' ;
# One of the queries are invalid: index = 24, query:SELECT count(attendance.link_to_member) FROM attendance INNER JOIN event ON attendance.link_to_event = event.event_id WHERE event.event_name = 'Women\'s Soccer'
# progress:  6580
# One of the queries are invalid: index = 21, query:SELECT T1.phone FROM member AS T1 JOIN attendance AS T2 ON T1.member_id = T2.link_to_member JOIN event AS T3 ON T2.link_to_event = T3.event_id WHERE T3.event_name = 'Women\'s Soccer'
# One of the queries are invalid: index = 23, query:SELECT T1.phone FROM member AS T1 JOIN attendance AS T2 ON T1.member_id = T2.link_to_member JOIN event AS T3 ON T2.link_to_event = T3.event_id WHERE T3.event_name = 'Women\'s Soccer' AND T1.position = 'Student_Club'
# progress:  6585
# progress:  6590
# progress:  6595
# progress:  6600
# progress:  6605
# progress:  6610
# progress:  6615
# progress:  6620
# progress:  6625
# progress:  6630
# progress:  6635
# progress:  6640
# progress:  6645
# progress:  6650
# progress:  6655
# progress:  6660
# progress:  6665
# progress:  6670
# progress:  6675
# progress:  6680
# progress:  6685
# progress:  6690
# progress:  6695
# progress:  6700
# progress:  6705
# progress:  6710
# progress:  6715
# progress:  6720
# progress:  6725
# progress:  6730
# progress:  6735
# One of the queries are invalid: index = 9, query:SELECT T2.county FROM member AS T1 JOIN zip_code AS T2 ON T1.zip = T2.zip_code WHERE T1.first_name = 'Adela' AND T1.last_name = 'O\'Gallagher'
# One of the queries are invalid: index = 12, query:SELECT T2.county FROM member AS T1 JOIN zip_code AS T2 ON T1.zip = T2.zip_code WHERE T1.first_name = 'Adela' AND T1.last_name = 'O\'Gallagher'
# One of the queries are invalid: index = 13, query:SELECT T2.county FROM member AS T1 JOIN zip_code AS T2 ON T1.zip = T2.zip_code WHERE T1.first_name = 'Adela' AND T1.last_name = 'O\'Gallagher' ;
# One of the queries are invalid: index = 19, query:SELECT T2.county FROM member AS T1 JOIN zip_code AS T2 ON T1.zip = T2.zip_code WHERE T1.first_name = 'Adela' AND T1.last_name = 'O\'Gallagher'
# One of the queries are invalid: index = 24, query:SELECT T2.county FROM member AS T1 INNER JOIN zip_code AS T2 ON T1.zip = T2.zip_code WHERE T1.first_name = 'Adela' AND T1.last_name = 'O\'Gallagher'
# progress:  6740
# progress:  6745
# progress:  6750
# progress:  6755
# progress:  6760
# progress:  6765
# progress:  6770
# progress:  6775
# progress:  6780
# progress:  6785
# progress:  6790
# progress:  6795
# progress:  6800
# progress:  6805
# progress:  6810
# progress:  6815
# progress:  6820
# progress:  6825
# progress:  6830
# progress:  6835
# progress:  6840
# progress:  6845
# progress:  6850
# progress:  6855
# One of the queries are invalid: index = 9, query:SELECT count(attendance.link_to_member) FROM attendance INNER JOIN event ON attendance.link_to_event = event.event_id WHERE event.event_name = 'Women\'s Soccer' ;
# One of the queries are invalid: index = 17, query:SELECT count(attendance.link_to_member) FROM attendance INNER JOIN event ON attendance.link_to_event = event.event_id INNER JOIN member ON attendance.link_to_member = member.member_id INNER JOIN zip_code ON member.zip = zip_code.zip_code WHERE event.event_name = 'Women\'s Soccer' AND member.position = 'Member' AND zip_code.city = 'Many' ;
# One of the queries are invalid: index = 24, query:SELECT count(attendance.link_to_member) FROM attendance INNER JOIN event ON attendance.link_to_event = event.event_id INNER JOIN member ON attendance.link_to_member = member.member_id INNER JOIN zip_code ON member.zip = zip_code.zip_code WHERE event.event_name = 'Women\'s Soccer' AND member.position = 'Member' AND zip_code.city = 'Many' ;
# progress:  6860
# progress:  6865
# progress:  6870
# progress:  6875
# progress:  6880
# progress:  6885
# progress:  6890
# progress:  6895
# progress:  6900
# progress:  6905
# progress:  6910
# progress:  6915
# progress:  6920
# progress:  6925
# progress:  6930
# progress:  6935
# progress:  6940
